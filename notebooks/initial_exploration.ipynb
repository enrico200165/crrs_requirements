# %%
import os.path

sys.path.insert(0, '../python/crrs_reqs')


filepath = os.path.join(g.path, g.filename_shk)
df = bld.reqs_from_word_file(filepath)
print(df.columns)
print(df[g.status_key][0:5])
print(df[g.status_key].value_counts())
# Out:
# Index(['rp_spec_id', 'req_id', 'name', 'description', 'status', 'source',
#        'rationale'],
#       dtype='object')
# 0    Postponed
# 1    Postponed
# 2    Postponed
# 3    Postponed
# 4     Proposed
# Name: status, dtype: object
# Postponed    46
# Proposed     25
# Name: status, dtype: int64

# %%
from IPython.display import display, HTML
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rp_spec_id</th>
#       <th>req_id</th>
#       <th>name</th>
#       <th>description</th>
#       <th>status</th>
#       <th>source</th>
#       <th>rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>REQ-01.12.01 (SHR)</td>
#       <td>IRS-REQ-00020</td>
#       <td>In relation to the processing of personal data in order to make it anonymous, eu-LISA shall be the data processor.</td>
#       <td>In relation to the processing of personal data in order to make it anonymous, eu-LISA shall be the data processor.</td>
#       <td>Postponed</td>
#       <td>01: DA CRRS operations data protection security (Draft)</td>
#       <td>01: Art. 7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>REQ-01.15.01 (SHR)</td>
#       <td>IRS-REQ-00230</td>
#       <td>The CRRS shall assign a data quality classification ("good" or "low") to all data entering the CRRS, calculate data quality profile and apply data quality standards  For low quality data a data quality alert must be generated.</td>
#       <td>The CRRS shall assign a data quality classification ("good" or "low") to all data entering the CRRS, calculate data quality profile and apply data quality standards  For low quality data a data quality alert must be generated</td>
#       <td>Postponed</td>
#       <td>01: Annex 7. Business Use Cases CRRS\n02: IoP_IA_Data quality mechanisms_v8.1 (Draft)</td>
#       <td>01: Section 4.1; Section 5.1\n02: Art. 3(2); Art. 3(3)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>REQ-02.09.01 (SHR)</td>
#       <td>IRS-REQ-00231</td>
#       <td>The CRRS shall use a technical solution hosting the isolated CRRS information.</td>
#       <td>The CRRS shall use a technical solution hosting the isolated CRRS information.</td>
#       <td>Postponed</td>
#       <td>01: DA CRRS operations data protection security (Draft)</td>
#       <td>01. Art. 3(1)</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>REQ-02.10.01 (SHR)</td>
#       <td>IRS-REQ-00232</td>
#       <td>The anonymization process in CRRS shall be carried out via automated processes and shall be irreversible.</td>
#       <td>The anonymization process in CRRS shall be carried out via automated processes and shall be irreversible.</td>
#       <td>Postponed</td>
#       <td>01: DA CRRS operations data protection security (Draft)</td>
#       <td>01. Art. 5(2)</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>REQ-02.10.02 (SHR)</td>
#       <td>IRS-REQ-00233</td>
#       <td>The CRRS shall Anonymise and store data in CRRS Connector. Receive data from : SIS, Eurodac, ECRIS-TCN, EES, VIS, ETIAS, CIR, MID, sBMS, ESP and CTL and ITSM systems. Then the data shall be assigned with data quality classification ("good" or "low") and</td>
#       <td>The CRRS shall Anonymise and store data in CRRS Connector. Receive data from : SIS, Eurodac, ECRIS-TCN, EES, VIS, ETIAS, CIR, MID, sBMS, ESP \nand CTL and ITSM systems. Then the data shall be assigned with data quality classification ("good" or "low") and anonymised (transform data to state that does not allow for identification of individuals) before the data is stored in CRRS connector. CTL is Common Technology Layer</td>
#       <td>Proposed</td>
#       <td>01: Annex 7. Business Use Cases CRRS\n02: 02019R0817-20190522 - Interoperability Regulation (EU) 2019/817\n03: 02019R0818-20190522 - Interoperability Regulation (EU) 2019/818</td>
#       <td>01: Section 4.2; Section 5.2\n02: Art. 39(3)\n03: Art. 39(3)</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>REQ-02.10.03 (SHR)</td>
#       <td>IRS-REQ-00234</td>
#       <td>The CRRS shall identify critical identity data in the EU information systems and shall anonymise it via automated means before storing any statistical data in the CRRS.</td>
#       <td>The CRRS shall identify critical identity data in the EU information systems and shall anonymise it via automated means before storing any statistical data in the CRRS.</td>
#       <td>Postponed</td>
#       <td>01: DA CRRS operations data protection security (Draft)</td>
#       <td>01. Art. 5(3)</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>REQ-02.10.04 (SHR)</td>
#       <td>IRS-REQ-00235</td>
#       <td>All data which is extracted into the CRRS shall be anonymised via an anonymization process in the CRRS. Only anonymised data shall be stored in the CRRS.</td>
#       <td>All data which is extracted into the CRRS shall be anonymised via an anonymization process in the CRRS. Only anonymised data shall be stored in the CRRS.</td>
#       <td>Postponed</td>
#       <td>01: DA CRRS operations data protection security (Draft)</td>
#       <td>01. Art. 5(1)</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>REQ-02.11.01 (SHR)</td>
#       <td>IRS-REQ-00236</td>
#       <td>All data which is extracted into the CRRS shall be anonymised via an anonymization process in the CRRS. Only anonymised data shall be stored in the CRRS.</td>
#       <td>All data which is extracted into the CRRS shall be anonymised via an anonymization process in the CRRS. Only anonymised data shall be stored in the CRRS.</td>
#       <td>Postponed</td>
#       <td>01: DA CRRS operations data protection security (Draft)</td>
#       <td>01. Art. 5(1)</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>REQ-02.21.01 (SHR)</td>
#       <td>IRS-REQ-00237</td>
#       <td>The CRRS shall made available and store the data for  reporting and statistical purposes.</td>
#       <td>The CRRS shall made available to the duly authorised staff of the competent authorities of Member States, the Commission and eu-LISA, and shall store the following data for reporting and statistics purposes.\na) Application status information; \nb) Nationalities, sex and year of birth of the applicant; \nc) The country of residence; \nd) Education (primary, secondary, higher or none); \ne) Current occupation (job group); \nf) The type of the travel document and three-letter code of the issuing country; \ng) The type of travel authorization and, for a travel authorization with limited territorial validity a reference to the Member State(s) issuing the travel authorization with limited territorial validity; \nh) The validity period of the travel authorization; and \ni) The grounds for refusing, revoking or annulling a travel authorization.\nThe duly authorised staff of the competent authorities of Member States, the Commission, eu-LISA and the ETIAS Central Unit shall allow CRRS to access to consult those data in EU Information Systems: SIS, Eurodac, ECRIS-TCN, EES, VIS, ETIAS, CIR, MID, sBMS, ESP and CTL and ITSM systems.</td>
#       <td>Postponed</td>
#       <td>01: DA CRRS operations data protection security (Draft)</td>
#       <td>01: Art. 2(1)</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>REQ-03.03.01 (SHR)</td>
#       <td>IRS-REQ-00238</td>
#       <td>The CRRS shall keep a unique reference number.</td>
#       <td>The CRRS shall keep a unique reference number allowing to keep trace of the fact that identity files from within or between the corresponding EU information systems were cross-matched for relevant statistical purposes. This reference number shall not allow retrieving the underlying identity files.</td>
#       <td>Postponed</td>
#       <td>01: DA CRRS operations data protection security (Draft)</td>
#       <td>01: Art. 2(4)</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>REQ-03.04.01 (SHR)</td>
#       <td>IRS-REQ-00239</td>
#       <td>The CRRS shall contain statistical data, including reports, on system usage for the purposes of monitoring the functioning of the interoperability components.</td>
#       <td>The CRRS shall contain statistical data, including reports, on system usage for the purposes of monitoring the functioning of the interoperability components.</td>
#       <td>Postponed</td>
#       <td>01: DA CRRS operations data protection security (Draft)</td>
#       <td>01: Art. 2(2)</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>REQ-03.04.02 (SHR)</td>
#       <td>IRS-REQ-00240</td>
#       <td>T
